# %%
from src.landscape_functions import build_sop_landscape

# %%
nc = 2
rho = 1/nc
c = 0.01
L = 256
result = build_sop_landscape(
    c=c,
    rho=rho,
    L=L,
    dim=3,
    num_colors=nc,
    base_raw="../SOP_data/raw",
    type_perc="bond_percolation",
    value_mode="species",          # P(p^i | f_T)
    weight_mode="equal_file_color",
    p_min=0.0,
    p_max=1.0,
    n_bins=120,
    make_plots=True,
    save_outputs=False,
)

# Mean between species
# result = build_sop_landscape(
#     c=0.15,
#     rho=0.25,
#     L=128,
#     dim=3,
#     num_colors=4,
#     value_mode="mean",
#     weight_mode="equal_file",
# )

# Arrays available after running:
fT_values = result["fT_values"]
p_centers = result["p_centers"]
P = result["P"]
V = result["V"]
samples = result["samples"]
summary = result["summary"]
# Out:
# Root used: ../SOP_data/raw/bond_percolation/num_colors_2/dim_3/L_256/fT_constant
# JSON files found after c/rho filter: 12368
# ...
#  - ../SOP_data/raw/bond_percolation/num_colors_2/dim_3/L_256/fT_constant/fT_1.000000e-03/c_1.000000e-02/rho_5.0000e-01/data/apolo2_seed_1009996721_ts_20260513T132758_P0_0.10_p0_0.60.json :: No stationary pt values found in: ../SOP_data/raw/bond_percolation/num_colors_2/dim_3/L_256/fT_constant/fT_1.000000e-03/c_1.000000e-02/rho_5.0000e-01/data/apolo2_seed_1009996721_ts_20260513T132758_P0_0.10_p0_0.60.json
#  - ../SOP_data/raw/bond_percolation/num_colors_2/dim_3/L_256/fT_constant/fT_1.000000e-03/c_1.000000e-02/rho_5.0000e-01/data/apolo2_seed_1017209082_ts_20260513T130413_P0_0.10_p0_0.60.json :: No stationary pt values found in: ../SOP_data/raw/bond_percolation/num_colors_2/dim_3/L_256/fT_constant/fT_1.000000e-03/c_1.000000e-02/rho_5.0000e-01/data/apolo2_seed_1017209082_ts_20260513T130413_P0_0.10_p0_0.60.json
# ...
