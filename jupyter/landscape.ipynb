# %%
from src.landscape_functions import build_sop_landscape

# %%
nc = 1
rho = 1/nc
c = 0.01
L = 512
result = build_sop_landscape(
    c=c,
    rho=rho,
    L=L,
    dim=3,
    num_colors=nc,
    base_raw="../SOP_data/raw",
    type_perc="bond_percolation",
    value_mode="species",          # P(p^i | f_T)
    weight_mode="equal_file_color",
    p_min=0.0,
    p_max=1.0,
    n_bins=120,
    make_plots=True,
    save_outputs=False,
)

# Mean between species
# result = build_sop_landscape(
#     c=0.15,
#     rho=0.25,
#     L=128,
#     dim=3,
#     num_colors=4,
#     value_mode="mean",
#     weight_mode="equal_file",
# )

# Arrays available after running:
fT_values = result["fT_values"]
p_centers = result["p_centers"]
P = result["P"]
V = result["V"]
samples = result["samples"]
summary = result["summary"]
# Out:
# Root used: ../SOP_data/raw/bond_percolation/num_colors_1/dim_3/L_512/fT_constant
# JSON files found after c/rho filter: 416
# Warning: 27 files failed and were ignored. First failures:
#  - ../SOP_data/raw/bond_percolation/num_colors_1/dim_3/L_512/fT_constant/fT_1.000000e-03/c_1.000000e-02/rho_1.0000e+00/data/light_seed_1203276552_ts_20260513T131345_P0_0.10_p0_0.60.json :: No stationary pt values found in: ../SOP_data/raw/bond_percolation/num_colors_1/dim_3/L_512/fT_constant/fT_1.000000e-03/c_1.000000e-02/rho_1.0000e+00/data/light_seed_1203276552_ts_20260513T131345_P0_0.10_p0_0.60.json
#  - ../SOP_data/raw/bond_percolation/num_colors_1/dim_3/L_512/fT_constant/fT_1.000000e-03/c_1.000000e-02/rho_1.0000e+00/data/light_seed_1271064739_ts_20260513T131355_P0_0.10_p0_0.60.json :: No stationary pt values found in: ../SOP_data/raw/bond_percolation/num_colors_1/dim_3/L_512/fT_constant/fT_1.000000e-03/c_1.000000e-02/rho_1.0000e+00/data/light_seed_1271064739_ts_20260513T131355_P0_0.10_p0_0.60.json
#  - ../SOP_data/raw/bond_percolation/num_colors_1/dim_3/L_512/fT_constant/fT_1.000000e-03/c_1.000000e-02/rho_1.0000e+00/data/light_seed_1283774021_ts_20260513T131423_P0_0.10_p0_0.60.json :: No stationary pt values found in: ../SOP_data/raw/bond_percolation/num_colors_1/dim_3/L_512/fT_constant/fT_1.000000e-03/c_1.000000e-02/rho_1.0000e+00/data/light_seed_1283774021_ts_20260513T131423_P0_0.10_p0_0.60.json
#  - ../SOP_data/raw/bond_percolation/num_colors_1/dim_3/L_512/fT_constant/fT_1.000000e-03/c_1.000000e-02/rho_1.0000e+00/data/light_seed_1286704438_ts_20260513T131406_P0_0.10_p0_0.60.json :: No stationary pt values found in: ../SOP_data/raw/bond_percolation/num_colors_1/dim_3/L_512/fT_constant/fT_1.000000e-03/c_1.000000e-02/rho_1.0000e+00/data/light_seed_1286704438_ts_20260513T131406_P0_0.10_p0_0.60.json
#  - ../SOP_data/raw/bond_percolation/num_colors_1/dim_3/L_512/fT_constant/fT_1.000000e-03/c_1.000000e-02/rho_1.0000e+00/data/light_seed_1313930848_ts_20260513T131425_P0_0.10_p0_0.60.json :: No stationary pt values found in: ../SOP_data/raw/bond_percolation/num_colors_1/dim_3/L_512/fT_constant/fT_1.000000e-03/c_1.000000e-02/rho_1.0000e+00/data/light_seed_1313930848_ts_20260513T131425_P0_0.10_p0_0.60.json
#         f_T  n_files  n_rows    p_mean     p_std     p_min     p_max
# 0  0.013458       27   78668  0.250041  0.002258  0.245338  0.263410
# 1  0.025917       27   64364  0.250701  0.001548  0.246502  0.259161
# 2  0.038375       27   57199  0.251585  0.001322  0.245307  0.259102
# 3  0.050000      308  595184  0.252590  0.001146  0.247720  0.258635
