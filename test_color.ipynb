# %%
from python.src.network_functions import read_network
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 from python.src.network_functions import read_network
#
# File ~/Documents/self_organization_percolation/python/src/network_functions.py:3
#       1 import numpy as np
#       2 import pandas as pd
# ----> 3 from mayavi import mlab
#       4 import os
#       5 import matplotlib.pyplot as plt
#
# File ~/Documents/self_organization_percolation/.pyenv/lib/python3.12/site-packages/mayavi/mlab.py:16
#       8 # Author: Prabhu Ramachandran <prabhu_r@users.sf.net>
#       9 #         Gael Varoquaux <gael dot varoquaux at normalesup dot org>
#      10 # Copyright (c) 2007-2020, Enthought, Inc.
#    (...)     13
#      14 # Mayavi imports
#      15 from mayavi.core.common import process_ui_events
# ---> 16 from mayavi.tools.camera import view, roll, yaw, pitch, move
# ...
